# %% [markdown]
# # Web Mining Midterm Project
#
# # Question: ***What are the differences between trends at night and trends during the day?***
#
# ## Created by: Kevin Hart

# %% [markdown]
# ## Time Trending

# %%
from midterm_functions import popularity_table

popularity_table()
# Out:
# +------------+-----------------------+---------------+-------------------+---------+-----------+
# | Popularity |         Trend         |    Lifetime   | Lexical Diversity | Pos/Neg | Day/Night |
# +------------+-----------------------+---------------+-------------------+---------+-----------+
# |     1      |   #TuesdayMotivation  | 705.0 minutes |       0.854       |   pos   |    both   |
# |     2      |   #wednesdaythoughts  | 585.0 minutes |       0.890       |   pos   |   night   |
# |     3      |  #WednesdayMotivation | 585.0 minutes |       0.857       |   pos   |   night   |
# |     4      |     #LateLateJonas    | 585.0 minutes |       0.891       |   pos   |   night   |
# |     5      |    #NationalOREODay   | 525.0 minutes |       0.893       |   pos   |    both   |
# |     6      |     Chris Harrison    | 480.0 minutes |       0.956       |   pos   |    both   |
# |     7      |     #LukePerryRIP     | 480.0 minutes |       0.853       |   pos   |    both   |
# ...

# %% [markdown]
# ### Analysis:
#
# I started off by sorting the list of trends by the length of time they were trending. This let me basically sort the trends by how 'popular' they were. So the first interesting thing from this table we can see is that 12 of the top 15 trends were all hashtags and the other 3 are people. This makes sense becasue hashtags are a way for people to talk about a topic. The next interesting thing is when these things were actually trending. Most of the trends lasted from day into night or vice versa. It is also interesting that the out of the only 2 negative trends, 1 of them was only prevelant during the day. That leads me to believe that most of the time, only positive leaning trends are able to outlast the negative ones.

# %% [markdown]
# ## Sentiment Scores

# %%
from midterm_functions import plot_average_sentiments

plot_average_sentiments()

# %% [markdown]
# ### Analysis:
#
# This is a graph of the number of positive and negative trends based on whether it was day or night time. One thing I left out of this graph was that I actually compared them to neutral trends as well. I got rid of them because every trend was more neutral than positive or negative. So from this graph, we can see there were obviously more positive trends than negative trends. This could be because people usually like to keep a positive image about themselves so they will jump on more positive and encouraging trends than negative. Another thing we can gather is that there were actually more slightly more positive trends at night than during the day and there are more negative trends during the day than there are at night.

# %% [markdown]
# ## Lexical Diversity

# %%
from midterm_functions import plot_lex_divs

plot_lex_divs()

# %% [markdown]
# ### Analysis:
#
# This graph is suppposed to look at the differences in average lexical diversity between day and night, but there is basically no difference. While I think it could have been interesting to see a difference, I think it is also interesting that there is no difference. I even currently ignore tweets that are less than 3 words long, which would mean they might just have the trend, an emoji, and maybe another word. When I increased the mininum amount of words they stayed similar and only the total decreased.

# %% [markdown]
# ## Day and Night Difference

# %%
from midterm_functions import plot_day_night_trends

plot_day_night_trends()

# %% [markdown]
# ### Analysis:
#
# This pie chart represents what percentage of unique trends are happening throughout the day. From this chart we can see that most trends tended to last either from night into day or vice versa. As we can see, most of the trends go between day and night. This should be be sort of expected because people are usually working during the day and sleeping at night. This means that there towards the beginning and end of the day, there is more free time to do things.

# %% [markdown]
# ## Average Lifetime of Trends

# %%
from midterm_functions import plot_length_trends

plot_length_trends()
print('Overall: ~' + str(170) + ' minutes', end='\t\t') 
print('Day/Night: ~' + str(325) + ' minutes')
print('Only Night: ~' +  str(125) + ' minutes', end='\t')
print('Only Day: ~' +  str(140) + ' minutes')
# Out:
# Overall: ~170 minutes		Day/Night: ~325 minutes
# Only Night: ~125 minutes	Only Day: ~140 minutes

# %% [markdown]
# ### Analysis:
#
# This was my original question but a decided that it was to narrow and found more interesting results when looking at the difference between day and night. This graph gives us similar results to the pie chart above this graph. Trends that lasted from day into night or vice versa were almost twice as long as the overall average length of trends. Another thing from this graph is night trends were about 15 minutes shorter than trends during the day. This could be because there are less people online during the night in the US so trends didn't stay as active as they would during the day.

# %% [markdown]
# ## Conclusion:
#
# In conclusion, there are a bunch of differences between day and night trends, but there is also multiple similarities between them. After it all, trends usually positive and only lasted about 3 hours and were mainly changing inbetween night and day when people weren't working/busy. There also was not much of an overall differences in lexical diversity between day and night trends so people are just as lexically diverse during the day as they are at night. However, trends during the day tended to be longer as the day takes up the larger part of 24 hours. Trends at night also consisted of less negative trends than trends during the day. Finally trends mostly involve hashtags because that is kind of like a group that you're joining when you type the #'trend'.
#
# Trends are very interesting to look at because they are the things that people are thinking about currently. There is so much more I know I could do with this project if I had gathered more that 55 hours of data. I definitely would like to pursue this kind of large scale collection in the future.
